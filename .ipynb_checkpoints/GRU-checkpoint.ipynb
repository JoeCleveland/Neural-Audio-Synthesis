# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchaudio
import matplotlib.pyplot as plt
import numpy as np
import os
import json

# %%
#Change this to the location of the NSynth dataset on your machine
files = os.listdir('/media/data/nsynth-train/audio')

# %%
LEN = 256 #Length of the audio files
FILES = 6 #Number of files to use in a batch
SEGMN = 1 #Number of segments to take per file
BATCH = FILES * SEGMN #Batch size
START = 3000 #Start location of the audio 
NF = 0.05 #'Noise floor' i.e. amount of noise to add for regularization
BITR = 64 #Bit rate used for crossentropy loss / mu-law encoding

# %%
X = torch.zeros(BATCH, LEN)
Param = torch.zeros(BATCH, 1)

for f in range(FILES):
    #Change this to the location of the NSynth dataset on your machine
    sound, sr = torchaudio.load('/media/data/nsynth-train/audio/brass_acoustic_037-0'+str(f*2+60)+'-100.wav')
    for b in range(SEGMN):
        #Normalize the audio from 0 to 1
        clip = sound[:, START:START+LEN]
        clip = clip - clip.min() + NF*2
        clip = clip / (clip.max() + NF*2)

        X[f*SEGMN + b] = clip
        Param[f*SEGMN + b] = torch.tensor(f/FILES)

# %%
class Network(nn.Module):
    def __init__(self, statesize, outsize, paramsize):
        super(Network, self).__init__()
        self.statesize = statesize
        
        self.gateLayer1 = nn.GRUCell(1 + paramsize, statesize)
        #self.gateLayer2 = nn.GRUCell(statesize, statesize)
        #self.gateLayer3 = nn.GRUCell(statesize, statesize)
        #self.gateLayer4 = nn.GRUCell(statesize, statesize)
        
        self.linOut = nn.Linear(statesize, outsize)   
    
    def forward(self, inpt, state, param):

        newstate1 = self.gateLayer1(torch.cat((inpt, param), 1), state[:, 0])
        #newstate2 = self.gateLayer2(newstate1, state[:, 1])
        #newstate3 = self.gateLayer3(newstate2, state[:, 2])
        #newstate4 = self.gateLayer4(newstate3, state[:, 3])

        output = self.linOut(newstate1)
        
        #newstate = torch.cat((newstate1.view(-1, 1, self.statesize), 
        #                      newstate2.view(-1, 1, self.statesize), 
        #                      newstate3.view(-1, 1, self.statesize),
        #                      newstate4.view(-1, 1, self.statesize)), 1)
        return output, newstate1.view(-1, 1, self.statesize)

# %%
def muLaw(tensor):
    return torch.log(1 + (BITR-1)*torch.abs(tensor)) / np.log(BITR)

# %%
STATE = 40

rnn = Network(STATE, BITR, 1)
optimizer = optim.Adam(rnn.parameters(), lr=0.003)

# %%
#rnn = rnn.cuda()
#X = X.cuda()
#Param = Param.cuda()

NEPOCH = 100

for epoch in range(0, NEPOCH):
    
    state = torch.zeros(BATCH, 1, STATE)
    output = torch.zeros(BATCH, 1)
    loss = 0
    
    for step in range(1, X.shape[1]):
        
        #if epoch < NEPOCH/2:
        inpt = muLaw(X[:, step-1]).view(-1, 1)
        #else:
        #inpt = muLaw((torch.argmax(output, dim=1).float()/BITR)).view(-1, 1)
        inpt += torch.randn(1).view(-1, 1) * NF

        output, state = rnn(inpt, state, Param)
        
        loss += F.cross_entropy(output, (X[:, step] * (BITR-1)).long())
        #loss += F.mse_loss(output, X[:, step])
        
        if step % 32 == 31:
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            state = state.detach()    
            output = output.detach()
            print(epoch, "::", loss/32)
            loss = 0 
    

torch.save(rnn.state_dict(), 'model_1.mdl')
# Out:
# 0 :: tensor(1.3721, grad_fn=<DivBackward0>)
# 0 :: tensor(1.2350, grad_fn=<DivBackward0>)
# 0 :: tensor(1.3522, grad_fn=<DivBackward0>)
# 0 :: tensor(1.2083, grad_fn=<DivBackward0>)
# 0 :: tensor(1.1460, grad_fn=<DivBackward0>)
# 0 :: tensor(1.1484, grad_fn=<DivBackward0>)
# 0 :: tensor(1.4317, grad_fn=<DivBackward0>)
# 0 :: tensor(1.2336, grad_fn=<DivBackward0>)
# 1 :: tensor(1.3410, grad_fn=<DivBackward0>)
# 1 :: tensor(1.2183, grad_fn=<DivBackward0>)
# 1 :: tensor(1.4204, grad_fn=<DivBackward0>)
# 1 :: tensor(1.4884, grad_fn=<DivBackward0>)
# 1 :: tensor(1.1124, grad_fn=<DivBackward0>)
# 1 :: tensor(1.1987, grad_fn=<DivBackward0>)
# 1 :: tensor(1.6066, grad_fn=<DivBackward0>)
# 1 :: tensor(1.2522, grad_fn=<DivBackward0>)
# 2 :: tensor(1.3534, grad_fn=<DivBackward0>)
# 2 :: tensor(1.3038, grad_fn=<DivBackward0>)
# 2 :: tensor(1.3389, grad_fn=<DivBackward0>)
# 2 :: tensor(1.2359, grad_fn=<DivBackward0>)
# 2 :: tensor(1.1835, grad_fn=<DivBackward0>)
# 2 :: tensor(1.1586, grad_fn=<DivBackward0>)
# 2 :: tensor(1.4132, grad_fn=<DivBackward0>)
# 2 :: tensor(1.1530, grad_fn=<DivBackward0>)
# 3 :: tensor(1.3873, grad_fn=<DivBackward0>)
# 3 :: tensor(1.3951, grad_fn=<DivBackward0>)
# 3 :: tensor(1.2207, grad_fn=<DivBackward0>)
# 3 :: tensor(1.1848, grad_fn=<DivBackward0>)
# 3 :: tensor(1.0770, grad_fn=<DivBackward0>)
# 3 :: tensor(1.0497, grad_fn=<DivBackward0>)
# 3 :: tensor(1.6116, grad_fn=<DivBackward0>)
# 3 :: tensor(1.2456, grad_fn=<DivBackward0>)
# 4 :: tensor(1.3211, grad_fn=<DivBackward0>)
# 4 :: tensor(1.2287, grad_fn=<DivBackward0>)
# 4 :: tensor(1.2815, grad_fn=<DivBackward0>)
# 4 :: tensor(1.3001, grad_fn=<DivBackward0>)
# 4 :: tensor(1.1924, grad_fn=<DivBackward0>)
# 4 :: tensor(1.1862, grad_fn=<DivBackward0>)
# 4 :: tensor(1.4268, grad_fn=<DivBackward0>)
# 4 :: tensor(1.1951, grad_fn=<DivBackward0>)
# 5 :: tensor(1.3157, grad_fn=<DivBackward0>)
# 5 :: tensor(1.3012, grad_fn=<DivBackward0>)
# 5 :: tensor(1.2609, grad_fn=<DivBackward0>)
# 5 :: tensor(1.2465, grad_fn=<DivBackward0>)
# 5 :: tensor(1.3236, grad_fn=<DivBackward0>)
# 5 :: tensor(1.1975, grad_fn=<DivBackward0>)
# 5 :: tensor(1.3421, grad_fn=<DivBackward0>)
# 5 :: tensor(1.1577, grad_fn=<DivBackward0>)
# 6 :: tensor(1.3051, grad_fn=<DivBackward0>)
# 6 :: tensor(1.2281, grad_fn=<DivBackward0>)
# 6 :: tensor(1.2092, grad_fn=<DivBackward0>)
# 6 :: tensor(1.2911, grad_fn=<DivBackward0>)
# 6 :: tensor(1.4539, grad_fn=<DivBackward0>)
# 6 :: tensor(1.2294, grad_fn=<DivBackward0>)
# 6 :: tensor(1.3295, grad_fn=<DivBackward0>)
# 6 :: tensor(1.1035, grad_fn=<DivBackward0>)
# 7 :: tensor(1.3322, grad_fn=<DivBackward0>)
# 7 :: tensor(1.2463, grad_fn=<DivBackward0>)
# 7 :: tensor(1.5048, grad_fn=<DivBackward0>)
# 7 :: tensor(1.5254, grad_fn=<DivBackward0>)
# 7 :: tensor(1.1223, grad_fn=<DivBackward0>)
# 7 :: tensor(1.2551, grad_fn=<DivBackward0>)
# 7 :: tensor(1.3336, grad_fn=<DivBackward0>)
# 7 :: tensor(1.1000, grad_fn=<DivBackward0>)
# 8 :: tensor(1.3004, grad_fn=<DivBackward0>)
# 8 :: tensor(1.2852, grad_fn=<DivBackward0>)
# 8 :: tensor(1.9293, grad_fn=<DivBackward0>)
# 8 :: tensor(1.4079, grad_fn=<DivBackward0>)
# 8 :: tensor(1.3556, grad_fn=<DivBackward0>)
# 8 :: tensor(1.3184, grad_fn=<DivBackward0>)
# 8 :: tensor(1.5554, grad_fn=<DivBackward0>)
# 8 :: tensor(1.1330, grad_fn=<DivBackward0>)
# 9 :: tensor(1.4227, grad_fn=<DivBackward0>)
# 9 :: tensor(1.2615, grad_fn=<DivBackward0>)
# 9 :: tensor(1.5220, grad_fn=<DivBackward0>)
# 9 :: tensor(1.3715, grad_fn=<DivBackward0>)
# 9 :: tensor(1.2948, grad_fn=<DivBackward0>)
# 9 :: tensor(1.3022, grad_fn=<DivBackward0>)
# 9 :: tensor(1.5022, grad_fn=<DivBackward0>)
# 9 :: tensor(1.1186, grad_fn=<DivBackward0>)
# 10 :: tensor(1.5015, grad_fn=<DivBackward0>)
# 10 :: tensor(1.3454, grad_fn=<DivBackward0>)
# 10 :: tensor(1.2927, grad_fn=<DivBackward0>)
# 10 :: tensor(1.3155, grad_fn=<DivBackward0>)
# 10 :: tensor(1.3093, grad_fn=<DivBackward0>)
# 10 :: tensor(1.2733, grad_fn=<DivBackward0>)
# 10 :: tensor(1.4648, grad_fn=<DivBackward0>)
# 10 :: tensor(1.2748, grad_fn=<DivBackward0>)
# 11 :: tensor(1.3363, grad_fn=<DivBackward0>)
# 11 :: tensor(1.2996, grad_fn=<DivBackward0>)
# 11 :: tensor(1.2999, grad_fn=<DivBackward0>)
# 11 :: tensor(1.2597, grad_fn=<DivBackward0>)
# 11 :: tensor(1.2575, grad_fn=<DivBackward0>)
# 11 :: tensor(1.4997, grad_fn=<DivBackward0>)
# 11 :: tensor(1.4622, grad_fn=<DivBackward0>)
# 11 :: tensor(1.0057, grad_fn=<DivBackward0>)
# 12 :: tensor(1.2878, grad_fn=<DivBackward0>)
# 12 :: tensor(1.1665, grad_fn=<DivBackward0>)
# 12 :: tensor(1.1794, grad_fn=<DivBackward0>)
# 12 :: tensor(1.1559, grad_fn=<DivBackward0>)
# 12 :: tensor(1.1167, grad_fn=<DivBackward0>)
# 12 :: tensor(1.3481, grad_fn=<DivBackward0>)
# 12 :: tensor(1.3790, grad_fn=<DivBackward0>)
# 12 :: tensor(1.0336, grad_fn=<DivBackward0>)
# 13 :: tensor(1.3166, grad_fn=<DivBackward0>)
# 13 :: tensor(1.2171, grad_fn=<DivBackward0>)
# 13 :: tensor(1.3517, grad_fn=<DivBackward0>)
# 13 :: tensor(1.1751, grad_fn=<DivBackward0>)
# 13 :: tensor(1.2082, grad_fn=<DivBackward0>)
# 13 :: tensor(1.1935, grad_fn=<DivBackward0>)
# 13 :: tensor(1.3181, grad_fn=<DivBackward0>)
# 13 :: tensor(1.0289, grad_fn=<DivBackward0>)
# 14 :: tensor(1.4588, grad_fn=<DivBackward0>)
# 14 :: tensor(1.1656, grad_fn=<DivBackward0>)
# 14 :: tensor(1.2999, grad_fn=<DivBackward0>)
# 14 :: tensor(1.3181, grad_fn=<DivBackward0>)
# 14 :: tensor(1.0538, grad_fn=<DivBackward0>)
# 14 :: tensor(1.1472, grad_fn=<DivBackward0>)
# 14 :: tensor(1.3396, grad_fn=<DivBackward0>)
# 14 :: tensor(1.1324, grad_fn=<DivBackward0>)
# 15 :: tensor(1.4937, grad_fn=<DivBackward0>)
# 15 :: tensor(1.4247, grad_fn=<DivBackward0>)
# 15 :: tensor(1.2307, grad_fn=<DivBackward0>)
# 15 :: tensor(1.3001, grad_fn=<DivBackward0>)
# 15 :: tensor(1.0569, grad_fn=<DivBackward0>)
# 15 :: tensor(1.1964, grad_fn=<DivBackward0>)
# 15 :: tensor(1.3279, grad_fn=<DivBackward0>)
# 15 :: tensor(1.2650, grad_fn=<DivBackward0>)
# 16 :: tensor(1.3510, grad_fn=<DivBackward0>)
# 16 :: tensor(1.1080, grad_fn=<DivBackward0>)
# 16 :: tensor(1.3224, grad_fn=<DivBackward0>)
# 16 :: tensor(1.2675, grad_fn=<DivBackward0>)
# 16 :: tensor(1.1576, grad_fn=<DivBackward0>)
# 16 :: tensor(1.3825, grad_fn=<DivBackward0>)
# 16 :: tensor(1.5491, grad_fn=<DivBackward0>)
# 16 :: tensor(1.1850, grad_fn=<DivBackward0>)
# 17 :: tensor(1.3421, grad_fn=<DivBackward0>)
# 17 :: tensor(1.1991, grad_fn=<DivBackward0>)
# 17 :: tensor(1.5984, grad_fn=<DivBackward0>)
# 17 :: tensor(1.3169, grad_fn=<DivBackward0>)
# 17 :: tensor(1.3109, grad_fn=<DivBackward0>)
# 17 :: tensor(1.4125, grad_fn=<DivBackward0>)
# 17 :: tensor(2.0189, grad_fn=<DivBackward0>)
# 17 :: tensor(1.2510, grad_fn=<DivBackward0>)
# 18 :: tensor(1.3137, grad_fn=<DivBackward0>)
# 18 :: tensor(1.3882, grad_fn=<DivBackward0>)
# 18 :: tensor(2.0029, grad_fn=<DivBackward0>)
# 18 :: tensor(1.7392, grad_fn=<DivBackward0>)
# 18 :: tensor(1.6641, grad_fn=<DivBackward0>)
# 18 :: tensor(1.9693, grad_fn=<DivBackward0>)
# 18 :: tensor(1.7265, grad_fn=<DivBackward0>)
# 18 :: tensor(1.4313, grad_fn=<DivBackward0>)
# 19 :: tensor(1.5267, grad_fn=<DivBackward0>)
# 19 :: tensor(1.6966, grad_fn=<DivBackward0>)
# 19 :: tensor(1.7172, grad_fn=<DivBackward0>)
# 19 :: tensor(1.6377, grad_fn=<DivBackward0>)
# 19 :: tensor(1.5928, grad_fn=<DivBackward0>)
# 19 :: tensor(1.7412, grad_fn=<DivBackward0>)
# 19 :: tensor(1.5380, grad_fn=<DivBackward0>)
# 19 :: tensor(1.3901, grad_fn=<DivBackward0>)
# 20 :: tensor(1.5005, grad_fn=<DivBackward0>)
# 20 :: tensor(1.2486, grad_fn=<DivBackward0>)
# 20 :: tensor(1.6223, grad_fn=<DivBackward0>)
# 20 :: tensor(2.0011, grad_fn=<DivBackward0>)
# 20 :: tensor(1.3493, grad_fn=<DivBackward0>)
# 20 :: tensor(1.4530, grad_fn=<DivBackward0>)
# 20 :: tensor(2.0108, grad_fn=<DivBackward0>)
# 20 :: tensor(1.8340, grad_fn=<DivBackward0>)
# 21 :: tensor(1.7459, grad_fn=<DivBackward0>)
# 21 :: tensor(1.2428, grad_fn=<DivBackward0>)
# 21 :: tensor(1.8918, grad_fn=<DivBackward0>)
# 21 :: tensor(1.8031, grad_fn=<DivBackward0>)
# 21 :: tensor(1.4027, grad_fn=<DivBackward0>)
# 21 :: tensor(1.9141, grad_fn=<DivBackward0>)
# 21 :: tensor(1.7313, grad_fn=<DivBackward0>)
# 21 :: tensor(1.4241, grad_fn=<DivBackward0>)
# 22 :: tensor(1.5049, grad_fn=<DivBackward0>)
# 22 :: tensor(1.3472, grad_fn=<DivBackward0>)
# 22 :: tensor(1.5094, grad_fn=<DivBackward0>)
# 22 :: tensor(1.5707, grad_fn=<DivBackward0>)
# 22 :: tensor(1.3092, grad_fn=<DivBackward0>)
# 22 :: tensor(1.5101, grad_fn=<DivBackward0>)
# 22 :: tensor(1.4378, grad_fn=<DivBackward0>)
# 22 :: tensor(1.3021, grad_fn=<DivBackward0>)
# 23 :: tensor(1.5432, grad_fn=<DivBackward0>)
# 23 :: tensor(1.3019, grad_fn=<DivBackward0>)
# 23 :: tensor(1.4993, grad_fn=<DivBackward0>)
# 23 :: tensor(1.7806, grad_fn=<DivBackward0>)
# 23 :: tensor(1.5617, grad_fn=<DivBackward0>)
# 23 :: tensor(1.5338, grad_fn=<DivBackward0>)
# 23 :: tensor(1.5215, grad_fn=<DivBackward0>)
# 23 :: tensor(1.2246, grad_fn=<DivBackward0>)
# 24 :: tensor(1.3785, grad_fn=<DivBackward0>)
# 24 :: tensor(1.3752, grad_fn=<DivBackward0>)
# 24 :: tensor(1.3541, grad_fn=<DivBackward0>)
# 24 :: tensor(1.5230, grad_fn=<DivBackward0>)
# 24 :: tensor(1.2550, grad_fn=<DivBackward0>)
# 24 :: tensor(1.3182, grad_fn=<DivBackward0>)
# 24 :: tensor(1.7403, grad_fn=<DivBackward0>)
# 24 :: tensor(1.2340, grad_fn=<DivBackward0>)
# 25 :: tensor(1.4202, grad_fn=<DivBackward0>)
# 25 :: tensor(1.3228, grad_fn=<DivBackward0>)
# 25 :: tensor(1.3756, grad_fn=<DivBackward0>)
# 25 :: tensor(1.4333, grad_fn=<DivBackward0>)
# 25 :: tensor(1.1902, grad_fn=<DivBackward0>)
# 25 :: tensor(1.1593, grad_fn=<DivBackward0>)
# 25 :: tensor(1.5110, grad_fn=<DivBackward0>)
# 25 :: tensor(1.1305, grad_fn=<DivBackward0>)
# 26 :: tensor(1.2949, grad_fn=<DivBackward0>)
# 26 :: tensor(1.2423, grad_fn=<DivBackward0>)
# 26 :: tensor(1.2444, grad_fn=<DivBackward0>)
# 26 :: tensor(1.3196, grad_fn=<DivBackward0>)
# 26 :: tensor(1.2944, grad_fn=<DivBackward0>)
# 26 :: tensor(1.2485, grad_fn=<DivBackward0>)
# 26 :: tensor(1.3673, grad_fn=<DivBackward0>)
# 26 :: tensor(1.0704, grad_fn=<DivBackward0>)
# 27 :: tensor(1.3155, grad_fn=<DivBackward0>)
# 27 :: tensor(1.2000, grad_fn=<DivBackward0>)
# 27 :: tensor(1.3502, grad_fn=<DivBackward0>)
# 27 :: tensor(1.3846, grad_fn=<DivBackward0>)
# 27 :: tensor(1.1778, grad_fn=<DivBackward0>)
# 27 :: tensor(1.2682, grad_fn=<DivBackward0>)
# 27 :: tensor(1.3698, grad_fn=<DivBackward0>)
# 27 :: tensor(1.1618, grad_fn=<DivBackward0>)
# 28 :: tensor(1.4652, grad_fn=<DivBackward0>)
# 28 :: tensor(1.2881, grad_fn=<DivBackward0>)
# 28 :: tensor(1.2580, grad_fn=<DivBackward0>)
# 28 :: tensor(1.3242, grad_fn=<DivBackward0>)
# 28 :: tensor(1.4220, grad_fn=<DivBackward0>)
# 28 :: tensor(1.1665, grad_fn=<DivBackward0>)
# 28 :: tensor(1.2828, grad_fn=<DivBackward0>)
# 28 :: tensor(1.0595, grad_fn=<DivBackward0>)
# 29 :: tensor(1.3688, grad_fn=<DivBackward0>)
# 29 :: tensor(1.2122, grad_fn=<DivBackward0>)
# 29 :: tensor(1.2881, grad_fn=<DivBackward0>)
# 29 :: tensor(1.3213, grad_fn=<DivBackward0>)
# 29 :: tensor(1.1886, grad_fn=<DivBackward0>)
# 29 :: tensor(1.3103, grad_fn=<DivBackward0>)
# 29 :: tensor(1.4211, grad_fn=<DivBackward0>)
# 29 :: tensor(1.1740, grad_fn=<DivBackward0>)
# 30 :: tensor(1.2675, grad_fn=<DivBackward0>)
# 30 :: tensor(1.1330, grad_fn=<DivBackward0>)
# 30 :: tensor(1.2673, grad_fn=<DivBackward0>)
# 30 :: tensor(1.3368, grad_fn=<DivBackward0>)
# 30 :: tensor(1.1387, grad_fn=<DivBackward0>)
# 30 :: tensor(1.1255, grad_fn=<DivBackward0>)
# 30 :: tensor(1.4703, grad_fn=<DivBackward0>)
# 30 :: tensor(1.0615, grad_fn=<DivBackward0>)
# 31 :: tensor(1.4499, grad_fn=<DivBackward0>)
# 31 :: tensor(1.3064, grad_fn=<DivBackward0>)
# 31 :: tensor(1.2816, grad_fn=<DivBackward0>)
# 31 :: tensor(1.2019, grad_fn=<DivBackward0>)
# 31 :: tensor(1.1727, grad_fn=<DivBackward0>)
# 31 :: tensor(1.1055, grad_fn=<DivBackward0>)
# 31 :: tensor(1.4421, grad_fn=<DivBackward0>)
# 31 :: tensor(1.0340, grad_fn=<DivBackward0>)
# 32 :: tensor(1.4190, grad_fn=<DivBackward0>)
# 32 :: tensor(1.0947, grad_fn=<DivBackward0>)
# 32 :: tensor(1.1418, grad_fn=<DivBackward0>)
# 32 :: tensor(1.1957, grad_fn=<DivBackward0>)
# 32 :: tensor(1.0692, grad_fn=<DivBackward0>)
# 32 :: tensor(1.2351, grad_fn=<DivBackward0>)
# 32 :: tensor(1.3395, grad_fn=<DivBackward0>)
# 32 :: tensor(1.1023, grad_fn=<DivBackward0>)
# 33 :: tensor(1.2615, grad_fn=<DivBackward0>)
# 33 :: tensor(1.1890, grad_fn=<DivBackward0>)
# 33 :: tensor(1.1731, grad_fn=<DivBackward0>)
# 33 :: tensor(1.2561, grad_fn=<DivBackward0>)
# 33 :: tensor(1.1245, grad_fn=<DivBackward0>)
# 33 :: tensor(1.1484, grad_fn=<DivBackward0>)
# 33 :: tensor(1.4080, grad_fn=<DivBackward0>)
# 33 :: tensor(1.0136, grad_fn=<DivBackward0>)
# 34 :: tensor(1.3797, grad_fn=<DivBackward0>)
# 34 :: tensor(1.2435, grad_fn=<DivBackward0>)
# 34 :: tensor(1.1640, grad_fn=<DivBackward0>)
# 34 :: tensor(1.1469, grad_fn=<DivBackward0>)
# 34 :: tensor(1.0368, grad_fn=<DivBackward0>)
# 34 :: tensor(1.1925, grad_fn=<DivBackward0>)
# 34 :: tensor(1.4050, grad_fn=<DivBackward0>)
# 34 :: tensor(0.9927, grad_fn=<DivBackward0>)
# 35 :: tensor(1.2383, grad_fn=<DivBackward0>)
# 35 :: tensor(1.1328, grad_fn=<DivBackward0>)
# 35 :: tensor(1.2202, grad_fn=<DivBackward0>)
# 35 :: tensor(1.3428, grad_fn=<DivBackward0>)
# 35 :: tensor(0.9880, grad_fn=<DivBackward0>)
# 35 :: tensor(0.9861, grad_fn=<DivBackward0>)
# 35 :: tensor(1.5913, grad_fn=<DivBackward0>)
# 35 :: tensor(1.1218, grad_fn=<DivBackward0>)
# 36 :: tensor(1.2522, grad_fn=<DivBackward0>)
# 36 :: tensor(1.0979, grad_fn=<DivBackward0>)
# 36 :: tensor(1.2679, grad_fn=<DivBackward0>)
# 36 :: tensor(1.1971, grad_fn=<DivBackward0>)
# 36 :: tensor(1.1635, grad_fn=<DivBackward0>)
# 36 :: tensor(1.1790, grad_fn=<DivBackward0>)
# 36 :: tensor(1.4209, grad_fn=<DivBackward0>)
# 36 :: tensor(0.9993, grad_fn=<DivBackward0>)
# 37 :: tensor(1.2688, grad_fn=<DivBackward0>)
# 37 :: tensor(1.1893, grad_fn=<DivBackward0>)
# 37 :: tensor(1.2663, grad_fn=<DivBackward0>)
# 37 :: tensor(1.3590, grad_fn=<DivBackward0>)
# 37 :: tensor(1.0741, grad_fn=<DivBackward0>)
# 37 :: tensor(1.1129, grad_fn=<DivBackward0>)
# 37 :: tensor(1.4208, grad_fn=<DivBackward0>)
# 37 :: tensor(1.1136, grad_fn=<DivBackward0>)
# 38 :: tensor(1.2163, grad_fn=<DivBackward0>)
# 38 :: tensor(1.2058, grad_fn=<DivBackward0>)
# 38 :: tensor(1.4277, grad_fn=<DivBackward0>)
# 38 :: tensor(1.4065, grad_fn=<DivBackward0>)
# 38 :: tensor(1.5546, grad_fn=<DivBackward0>)
# 38 :: tensor(1.2911, grad_fn=<DivBackward0>)
# 38 :: tensor(1.3989, grad_fn=<DivBackward0>)
# 38 :: tensor(1.1091, grad_fn=<DivBackward0>)
# 39 :: tensor(1.2776, grad_fn=<DivBackward0>)
# 39 :: tensor(1.0721, grad_fn=<DivBackward0>)
# 39 :: tensor(1.1402, grad_fn=<DivBackward0>)
# 39 :: tensor(1.2913, grad_fn=<DivBackward0>)
# 39 :: tensor(1.1302, grad_fn=<DivBackward0>)
# 39 :: tensor(1.1665, grad_fn=<DivBackward0>)
# 39 :: tensor(1.3692, grad_fn=<DivBackward0>)
# 39 :: tensor(0.9825, grad_fn=<DivBackward0>)
# 40 :: tensor(1.2653, grad_fn=<DivBackward0>)
# 40 :: tensor(1.1092, grad_fn=<DivBackward0>)
# 40 :: tensor(1.1542, grad_fn=<DivBackward0>)
# 40 :: tensor(1.3039, grad_fn=<DivBackward0>)
# 40 :: tensor(1.0827, grad_fn=<DivBackward0>)
# 40 :: tensor(1.2205, grad_fn=<DivBackward0>)
# 40 :: tensor(1.5525, grad_fn=<DivBackward0>)
# 40 :: tensor(1.1687, grad_fn=<DivBackward0>)
# 41 :: tensor(1.2322, grad_fn=<DivBackward0>)
# 41 :: tensor(1.0828, grad_fn=<DivBackward0>)
# 41 :: tensor(1.1291, grad_fn=<DivBackward0>)
# 41 :: tensor(1.2445, grad_fn=<DivBackward0>)
# 41 :: tensor(1.1207, grad_fn=<DivBackward0>)
# 41 :: tensor(1.2335, grad_fn=<DivBackward0>)
# 41 :: tensor(1.3688, grad_fn=<DivBackward0>)
# 41 :: tensor(1.1411, grad_fn=<DivBackward0>)
# 42 :: tensor(1.3323, grad_fn=<DivBackward0>)
# 42 :: tensor(1.3121, grad_fn=<DivBackward0>)
# 42 :: tensor(1.2591, grad_fn=<DivBackward0>)
# 42 :: tensor(1.3033, grad_fn=<DivBackward0>)
# 42 :: tensor(1.0523, grad_fn=<DivBackward0>)
# 42 :: tensor(1.0728, grad_fn=<DivBackward0>)
# 42 :: tensor(1.2405, grad_fn=<DivBackward0>)
# 42 :: tensor(1.0493, grad_fn=<DivBackward0>)
# 43 :: tensor(1.2395, grad_fn=<DivBackward0>)
# 43 :: tensor(1.1160, grad_fn=<DivBackward0>)
# 43 :: tensor(1.3585, grad_fn=<DivBackward0>)
# 43 :: tensor(1.1641, grad_fn=<DivBackward0>)
# 43 :: tensor(1.0435, grad_fn=<DivBackward0>)
# 43 :: tensor(1.1287, grad_fn=<DivBackward0>)
# 43 :: tensor(1.3997, grad_fn=<DivBackward0>)
# 43 :: tensor(1.0914, grad_fn=<DivBackward0>)
# 44 :: tensor(1.2722, grad_fn=<DivBackward0>)
# 44 :: tensor(1.1777, grad_fn=<DivBackward0>)
# 44 :: tensor(1.4110, grad_fn=<DivBackward0>)
# 44 :: tensor(1.5723, grad_fn=<DivBackward0>)
# 44 :: tensor(1.1137, grad_fn=<DivBackward0>)
# 44 :: tensor(1.1266, grad_fn=<DivBackward0>)
# 44 :: tensor(1.3064, grad_fn=<DivBackward0>)
# 44 :: tensor(1.0910, grad_fn=<DivBackward0>)
# 45 :: tensor(1.5455, grad_fn=<DivBackward0>)
# 45 :: tensor(1.2430, grad_fn=<DivBackward0>)
# 45 :: tensor(1.3074, grad_fn=<DivBackward0>)
# 45 :: tensor(1.2296, grad_fn=<DivBackward0>)
# 45 :: tensor(1.0075, grad_fn=<DivBackward0>)
# 45 :: tensor(1.2526, grad_fn=<DivBackward0>)
# 45 :: tensor(1.5386, grad_fn=<DivBackward0>)
# 45 :: tensor(1.2976, grad_fn=<DivBackward0>)
# 46 :: tensor(1.2238, grad_fn=<DivBackward0>)
# 46 :: tensor(1.1574, grad_fn=<DivBackward0>)
# 46 :: tensor(1.1234, grad_fn=<DivBackward0>)
# 46 :: tensor(1.1940, grad_fn=<DivBackward0>)
# 46 :: tensor(1.1982, grad_fn=<DivBackward0>)
# 46 :: tensor(1.1383, grad_fn=<DivBackward0>)
# 46 :: tensor(1.4299, grad_fn=<DivBackward0>)
# 46 :: tensor(1.0747, grad_fn=<DivBackward0>)
# 47 :: tensor(1.2791, grad_fn=<DivBackward0>)
# 47 :: tensor(1.6636, grad_fn=<DivBackward0>)
# 47 :: tensor(1.5473, grad_fn=<DivBackward0>)
# 47 :: tensor(1.2638, grad_fn=<DivBackward0>)
# 47 :: tensor(1.0428, grad_fn=<DivBackward0>)
# 47 :: tensor(1.0351, grad_fn=<DivBackward0>)
# 47 :: tensor(1.2970, grad_fn=<DivBackward0>)
# 47 :: tensor(1.0114, grad_fn=<DivBackward0>)
# 48 :: tensor(1.2431, grad_fn=<DivBackward0>)
# 48 :: tensor(1.1185, grad_fn=<DivBackward0>)
# 48 :: tensor(1.2284, grad_fn=<DivBackward0>)
# 48 :: tensor(1.1787, grad_fn=<DivBackward0>)
# 48 :: tensor(0.9995, grad_fn=<DivBackward0>)
# 48 :: tensor(1.1398, grad_fn=<DivBackward0>)
# 48 :: tensor(1.2962, grad_fn=<DivBackward0>)
# 48 :: tensor(0.9782, grad_fn=<DivBackward0>)
# 49 :: tensor(1.3133, grad_fn=<DivBackward0>)
# 49 :: tensor(1.1348, grad_fn=<DivBackward0>)
# 49 :: tensor(1.2532, grad_fn=<DivBackward0>)
# 49 :: tensor(1.3335, grad_fn=<DivBackward0>)
# 49 :: tensor(1.2273, grad_fn=<DivBackward0>)
# 49 :: tensor(1.8505, grad_fn=<DivBackward0>)
# 49 :: tensor(1.3547, grad_fn=<DivBackward0>)
# 49 :: tensor(1.0303, grad_fn=<DivBackward0>)
# 50 :: tensor(1.2930, grad_fn=<DivBackward0>)
# 50 :: tensor(1.1470, grad_fn=<DivBackward0>)
# 50 :: tensor(1.2976, grad_fn=<DivBackward0>)
# 50 :: tensor(1.3281, grad_fn=<DivBackward0>)
# 50 :: tensor(1.0343, grad_fn=<DivBackward0>)
# 50 :: tensor(1.2174, grad_fn=<DivBackward0>)
# 50 :: tensor(1.4318, grad_fn=<DivBackward0>)
# 50 :: tensor(1.1938, grad_fn=<DivBackward0>)
# 51 :: tensor(1.2182, grad_fn=<DivBackward0>)
# 51 :: tensor(1.0889, grad_fn=<DivBackward0>)
# 51 :: tensor(1.3964, grad_fn=<DivBackward0>)
# 51 :: tensor(1.2905, grad_fn=<DivBackward0>)
# 51 :: tensor(1.0396, grad_fn=<DivBackward0>)
# 51 :: tensor(1.1988, grad_fn=<DivBackward0>)
# 51 :: tensor(1.2726, grad_fn=<DivBackward0>)
# 51 :: tensor(1.0333, grad_fn=<DivBackward0>)
# 52 :: tensor(1.1935, grad_fn=<DivBackward0>)
# 52 :: tensor(1.1104, grad_fn=<DivBackward0>)
# 52 :: tensor(1.1994, grad_fn=<DivBackward0>)
# 52 :: tensor(1.2886, grad_fn=<DivBackward0>)
# 52 :: tensor(0.9792, grad_fn=<DivBackward0>)
# 52 :: tensor(1.0970, grad_fn=<DivBackward0>)
# 52 :: tensor(1.2558, grad_fn=<DivBackward0>)
# 52 :: tensor(0.9552, grad_fn=<DivBackward0>)
# 53 :: tensor(1.2103, grad_fn=<DivBackward0>)
# 53 :: tensor(1.0981, grad_fn=<DivBackward0>)
# 53 :: tensor(1.2062, grad_fn=<DivBackward0>)
# 53 :: tensor(1.2662, grad_fn=<DivBackward0>)
# 53 :: tensor(0.9965, grad_fn=<DivBackward0>)
# 53 :: tensor(1.1397, grad_fn=<DivBackward0>)
# 53 :: tensor(1.4061, grad_fn=<DivBackward0>)
# 53 :: tensor(1.1034, grad_fn=<DivBackward0>)
# 54 :: tensor(1.1563, grad_fn=<DivBackward0>)
# 54 :: tensor(1.0722, grad_fn=<DivBackward0>)
# 54 :: tensor(1.2393, grad_fn=<DivBackward0>)
# 54 :: tensor(1.3449, grad_fn=<DivBackward0>)
# 54 :: tensor(1.0497, grad_fn=<DivBackward0>)
# 54 :: tensor(0.9616, grad_fn=<DivBackward0>)
# 54 :: tensor(1.3972, grad_fn=<DivBackward0>)
# 54 :: tensor(1.0392, grad_fn=<DivBackward0>)
# 55 :: tensor(1.2974, grad_fn=<DivBackward0>)
# 55 :: tensor(1.2831, grad_fn=<DivBackward0>)
# 55 :: tensor(1.1911, grad_fn=<DivBackward0>)
# 55 :: tensor(1.1269, grad_fn=<DivBackward0>)
# 55 :: tensor(1.0285, grad_fn=<DivBackward0>)
# 55 :: tensor(1.0856, grad_fn=<DivBackward0>)
# 55 :: tensor(1.2347, grad_fn=<DivBackward0>)
# 55 :: tensor(1.0085, grad_fn=<DivBackward0>)
# 56 :: tensor(1.2544, grad_fn=<DivBackward0>)
# 56 :: tensor(1.1051, grad_fn=<DivBackward0>)
# 56 :: tensor(1.5211, grad_fn=<DivBackward0>)
# 56 :: tensor(1.1349, grad_fn=<DivBackward0>)
# 56 :: tensor(1.0705, grad_fn=<DivBackward0>)
# 56 :: tensor(1.1441, grad_fn=<DivBackward0>)
# 56 :: tensor(1.3422, grad_fn=<DivBackward0>)
# 56 :: tensor(1.0025, grad_fn=<DivBackward0>)
# 57 :: tensor(1.3081, grad_fn=<DivBackward0>)
# 57 :: tensor(1.1493, grad_fn=<DivBackward0>)
# 57 :: tensor(1.2474, grad_fn=<DivBackward0>)
# 57 :: tensor(1.1714, grad_fn=<DivBackward0>)
# 57 :: tensor(0.9641, grad_fn=<DivBackward0>)
# 57 :: tensor(1.0902, grad_fn=<DivBackward0>)
# 57 :: tensor(1.1639, grad_fn=<DivBackward0>)
# 57 :: tensor(1.0520, grad_fn=<DivBackward0>)
# 58 :: tensor(1.2648, grad_fn=<DivBackward0>)
# 58 :: tensor(1.0635, grad_fn=<DivBackward0>)
# 58 :: tensor(1.5038, grad_fn=<DivBackward0>)
# 58 :: tensor(1.3416, grad_fn=<DivBackward0>)
# 58 :: tensor(0.9997, grad_fn=<DivBackward0>)
# 58 :: tensor(1.0579, grad_fn=<DivBackward0>)
# 58 :: tensor(1.1899, grad_fn=<DivBackward0>)
# 58 :: tensor(1.0530, grad_fn=<DivBackward0>)
# 59 :: tensor(1.2834, grad_fn=<DivBackward0>)
# 59 :: tensor(1.1011, grad_fn=<DivBackward0>)
# 59 :: tensor(1.2761, grad_fn=<DivBackward0>)
# 59 :: tensor(1.0861, grad_fn=<DivBackward0>)
# 59 :: tensor(1.0018, grad_fn=<DivBackward0>)
# 59 :: tensor(0.9836, grad_fn=<DivBackward0>)
# 59 :: tensor(1.2236, grad_fn=<DivBackward0>)
# 59 :: tensor(0.9266, grad_fn=<DivBackward0>)
# 60 :: tensor(1.1247, grad_fn=<DivBackward0>)
# 60 :: tensor(1.0174, grad_fn=<DivBackward0>)
# 60 :: tensor(1.1704, grad_fn=<DivBackward0>)
# 60 :: tensor(1.2325, grad_fn=<DivBackward0>)
# 60 :: tensor(1.0029, grad_fn=<DivBackward0>)
# 60 :: tensor(1.0320, grad_fn=<DivBackward0>)
# 60 :: tensor(1.3530, grad_fn=<DivBackward0>)
# 60 :: tensor(1.0133, grad_fn=<DivBackward0>)
# 61 :: tensor(1.1478, grad_fn=<DivBackward0>)
# 61 :: tensor(1.1114, grad_fn=<DivBackward0>)
# 61 :: tensor(1.5423, grad_fn=<DivBackward0>)
# 61 :: tensor(1.4237, grad_fn=<DivBackward0>)
# 61 :: tensor(1.0188, grad_fn=<DivBackward0>)
# 61 :: tensor(1.2042, grad_fn=<DivBackward0>)
# 61 :: tensor(1.2572, grad_fn=<DivBackward0>)
# 61 :: tensor(1.0195, grad_fn=<DivBackward0>)
# 62 :: tensor(1.2797, grad_fn=<DivBackward0>)
# 62 :: tensor(1.5863, grad_fn=<DivBackward0>)
# 62 :: tensor(1.2758, grad_fn=<DivBackward0>)
# 62 :: tensor(1.1350, grad_fn=<DivBackward0>)
# 62 :: tensor(1.0425, grad_fn=<DivBackward0>)
# 62 :: tensor(1.0375, grad_fn=<DivBackward0>)
# 62 :: tensor(1.2845, grad_fn=<DivBackward0>)
# 62 :: tensor(1.1181, grad_fn=<DivBackward0>)
# 63 :: tensor(1.2025, grad_fn=<DivBackward0>)
# 63 :: tensor(1.1008, grad_fn=<DivBackward0>)
# 63 :: tensor(1.2875, grad_fn=<DivBackward0>)
# 63 :: tensor(1.4917, grad_fn=<DivBackward0>)
# 63 :: tensor(1.1623, grad_fn=<DivBackward0>)
# 63 :: tensor(1.2571, grad_fn=<DivBackward0>)
# 63 :: tensor(1.3318, grad_fn=<DivBackward0>)
# 63 :: tensor(1.0235, grad_fn=<DivBackward0>)
# 64 :: tensor(1.2057, grad_fn=<DivBackward0>)
# 64 :: tensor(1.0406, grad_fn=<DivBackward0>)
# 64 :: tensor(1.1964, grad_fn=<DivBackward0>)
# 64 :: tensor(1.2688, grad_fn=<DivBackward0>)
# 64 :: tensor(1.0826, grad_fn=<DivBackward0>)
# 64 :: tensor(1.1642, grad_fn=<DivBackward0>)
# 64 :: tensor(1.2889, grad_fn=<DivBackward0>)
# 64 :: tensor(0.9460, grad_fn=<DivBackward0>)
# 65 :: tensor(1.1793, grad_fn=<DivBackward0>)
# 65 :: tensor(1.1596, grad_fn=<DivBackward0>)
# 65 :: tensor(1.3174, grad_fn=<DivBackward0>)
# 65 :: tensor(1.3049, grad_fn=<DivBackward0>)
# 65 :: tensor(1.0425, grad_fn=<DivBackward0>)
# 65 :: tensor(1.1176, grad_fn=<DivBackward0>)
# 65 :: tensor(1.2378, grad_fn=<DivBackward0>)
# 65 :: tensor(1.2265, grad_fn=<DivBackward0>)
# 66 :: tensor(1.1695, grad_fn=<DivBackward0>)
# 66 :: tensor(1.0676, grad_fn=<DivBackward0>)
# 66 :: tensor(1.5313, grad_fn=<DivBackward0>)
# 66 :: tensor(1.4701, grad_fn=<DivBackward0>)
# 66 :: tensor(1.1846, grad_fn=<DivBackward0>)
# 66 :: tensor(1.2023, grad_fn=<DivBackward0>)
# 66 :: tensor(1.2410, grad_fn=<DivBackward0>)
# 66 :: tensor(0.9724, grad_fn=<DivBackward0>)
# 67 :: tensor(1.2377, grad_fn=<DivBackward0>)
# 67 :: tensor(1.1488, grad_fn=<DivBackward0>)
# 67 :: tensor(1.1959, grad_fn=<DivBackward0>)
# 67 :: tensor(1.3459, grad_fn=<DivBackward0>)
# 67 :: tensor(1.0831, grad_fn=<DivBackward0>)
# 67 :: tensor(1.0370, grad_fn=<DivBackward0>)
# 67 :: tensor(1.4175, grad_fn=<DivBackward0>)
# 67 :: tensor(1.0379, grad_fn=<DivBackward0>)
# 68 :: tensor(1.1580, grad_fn=<DivBackward0>)
# 68 :: tensor(1.0939, grad_fn=<DivBackward0>)
# 68 :: tensor(1.2084, grad_fn=<DivBackward0>)
# 68 :: tensor(1.1084, grad_fn=<DivBackward0>)
# 68 :: tensor(1.0296, grad_fn=<DivBackward0>)
# 68 :: tensor(1.1880, grad_fn=<DivBackward0>)
# 68 :: tensor(1.3127, grad_fn=<DivBackward0>)
# 68 :: tensor(1.0579, grad_fn=<DivBackward0>)
# 69 :: tensor(1.2104, grad_fn=<DivBackward0>)
# 69 :: tensor(1.0890, grad_fn=<DivBackward0>)
# 69 :: tensor(1.2980, grad_fn=<DivBackward0>)
# 69 :: tensor(1.4037, grad_fn=<DivBackward0>)
# 69 :: tensor(1.0128, grad_fn=<DivBackward0>)
# 69 :: tensor(0.9620, grad_fn=<DivBackward0>)
# 69 :: tensor(1.2321, grad_fn=<DivBackward0>)
# 69 :: tensor(0.9412, grad_fn=<DivBackward0>)
# 70 :: tensor(1.1710, grad_fn=<DivBackward0>)
# 70 :: tensor(1.0615, grad_fn=<DivBackward0>)
# 70 :: tensor(1.3327, grad_fn=<DivBackward0>)
# 70 :: tensor(1.1513, grad_fn=<DivBackward0>)
# 70 :: tensor(1.1428, grad_fn=<DivBackward0>)
# 70 :: tensor(1.3205, grad_fn=<DivBackward0>)
# 70 :: tensor(1.4456, grad_fn=<DivBackward0>)
# 70 :: tensor(1.0191, grad_fn=<DivBackward0>)
# 71 :: tensor(1.2002, grad_fn=<DivBackward0>)
# 71 :: tensor(1.0300, grad_fn=<DivBackward0>)
# 71 :: tensor(1.2094, grad_fn=<DivBackward0>)
# 71 :: tensor(1.1638, grad_fn=<DivBackward0>)
# 71 :: tensor(1.0064, grad_fn=<DivBackward0>)
# 71 :: tensor(1.0599, grad_fn=<DivBackward0>)
# 71 :: tensor(1.3579, grad_fn=<DivBackward0>)
# 71 :: tensor(1.0605, grad_fn=<DivBackward0>)
# 72 :: tensor(1.3220, grad_fn=<DivBackward0>)
# 72 :: tensor(1.1531, grad_fn=<DivBackward0>)
# 72 :: tensor(1.2048, grad_fn=<DivBackward0>)
# 72 :: tensor(1.2279, grad_fn=<DivBackward0>)
# 72 :: tensor(1.0527, grad_fn=<DivBackward0>)
# 72 :: tensor(1.1633, grad_fn=<DivBackward0>)
# 72 :: tensor(1.3322, grad_fn=<DivBackward0>)
# 72 :: tensor(0.9395, grad_fn=<DivBackward0>)
# 73 :: tensor(1.1673, grad_fn=<DivBackward0>)
# 73 :: tensor(1.6518, grad_fn=<DivBackward0>)
# 73 :: tensor(1.2555, grad_fn=<DivBackward0>)
# 73 :: tensor(1.4320, grad_fn=<DivBackward0>)
# 73 :: tensor(1.0976, grad_fn=<DivBackward0>)
# 73 :: tensor(1.2046, grad_fn=<DivBackward0>)
# 73 :: tensor(1.4956, grad_fn=<DivBackward0>)
# 73 :: tensor(0.9587, grad_fn=<DivBackward0>)
# 74 :: tensor(1.3188, grad_fn=<DivBackward0>)
# 74 :: tensor(1.1321, grad_fn=<DivBackward0>)
# 74 :: tensor(1.2531, grad_fn=<DivBackward0>)
# 74 :: tensor(1.2611, grad_fn=<DivBackward0>)
# 74 :: tensor(1.1256, grad_fn=<DivBackward0>)
# 74 :: tensor(1.0842, grad_fn=<DivBackward0>)
# 74 :: tensor(1.2357, grad_fn=<DivBackward0>)
# 74 :: tensor(1.0031, grad_fn=<DivBackward0>)
# 75 :: tensor(1.2767, grad_fn=<DivBackward0>)
# 75 :: tensor(1.1427, grad_fn=<DivBackward0>)
# 75 :: tensor(1.2047, grad_fn=<DivBackward0>)
# 75 :: tensor(1.1718, grad_fn=<DivBackward0>)
# 75 :: tensor(1.0551, grad_fn=<DivBackward0>)
# 75 :: tensor(1.2520, grad_fn=<DivBackward0>)
# 75 :: tensor(1.3442, grad_fn=<DivBackward0>)
# 75 :: tensor(0.9857, grad_fn=<DivBackward0>)
# 76 :: tensor(1.3183, grad_fn=<DivBackward0>)
# 76 :: tensor(1.2889, grad_fn=<DivBackward0>)
# 76 :: tensor(1.2440, grad_fn=<DivBackward0>)
# 76 :: tensor(1.5916, grad_fn=<DivBackward0>)
# 76 :: tensor(1.3318, grad_fn=<DivBackward0>)
# 76 :: tensor(1.2392, grad_fn=<DivBackward0>)
# 76 :: tensor(1.3498, grad_fn=<DivBackward0>)
# 76 :: tensor(1.0377, grad_fn=<DivBackward0>)
# 77 :: tensor(1.2723, grad_fn=<DivBackward0>)
# 77 :: tensor(1.2279, grad_fn=<DivBackward0>)
# 77 :: tensor(1.1607, grad_fn=<DivBackward0>)
# 77 :: tensor(1.2725, grad_fn=<DivBackward0>)
# 77 :: tensor(1.1200, grad_fn=<DivBackward0>)
# 77 :: tensor(1.2759, grad_fn=<DivBackward0>)
# 77 :: tensor(1.3571, grad_fn=<DivBackward0>)
# 77 :: tensor(0.9725, grad_fn=<DivBackward0>)
# 78 :: tensor(1.2267, grad_fn=<DivBackward0>)
# 78 :: tensor(1.2810, grad_fn=<DivBackward0>)
# 78 :: tensor(1.1405, grad_fn=<DivBackward0>)
# 78 :: tensor(1.2635, grad_fn=<DivBackward0>)
# 78 :: tensor(1.0970, grad_fn=<DivBackward0>)
# 78 :: tensor(1.0592, grad_fn=<DivBackward0>)
# 78 :: tensor(1.2651, grad_fn=<DivBackward0>)
# 78 :: tensor(0.9856, grad_fn=<DivBackward0>)
# 79 :: tensor(1.3896, grad_fn=<DivBackward0>)
# 79 :: tensor(1.1846, grad_fn=<DivBackward0>)
# 79 :: tensor(1.1528, grad_fn=<DivBackward0>)
# 79 :: tensor(1.1417, grad_fn=<DivBackward0>)
# 79 :: tensor(0.9597, grad_fn=<DivBackward0>)
# 79 :: tensor(1.0930, grad_fn=<DivBackward0>)
# 79 :: tensor(1.3031, grad_fn=<DivBackward0>)
# 79 :: tensor(0.9936, grad_fn=<DivBackward0>)
# 80 :: tensor(1.1571, grad_fn=<DivBackward0>)
# 80 :: tensor(1.0247, grad_fn=<DivBackward0>)
# 80 :: tensor(1.1126, grad_fn=<DivBackward0>)
# 80 :: tensor(1.1438, grad_fn=<DivBackward0>)
# 80 :: tensor(1.0202, grad_fn=<DivBackward0>)
# 80 :: tensor(0.9999, grad_fn=<DivBackward0>)
# 80 :: tensor(1.3164, grad_fn=<DivBackward0>)
# 80 :: tensor(0.9896, grad_fn=<DivBackward0>)
# 81 :: tensor(1.2094, grad_fn=<DivBackward0>)
# 81 :: tensor(1.0162, grad_fn=<DivBackward0>)
# 81 :: tensor(1.1304, grad_fn=<DivBackward0>)
# 81 :: tensor(1.1589, grad_fn=<DivBackward0>)
# 81 :: tensor(1.1566, grad_fn=<DivBackward0>)
# 81 :: tensor(1.0480, grad_fn=<DivBackward0>)
# 81 :: tensor(1.3563, grad_fn=<DivBackward0>)
# 81 :: tensor(0.9214, grad_fn=<DivBackward0>)
# 82 :: tensor(1.2722, grad_fn=<DivBackward0>)
# 82 :: tensor(1.0546, grad_fn=<DivBackward0>)
# 82 :: tensor(1.1814, grad_fn=<DivBackward0>)
# 82 :: tensor(1.3438, grad_fn=<DivBackward0>)
# 82 :: tensor(1.1750, grad_fn=<DivBackward0>)
# 82 :: tensor(1.0342, grad_fn=<DivBackward0>)
# 82 :: tensor(1.2186, grad_fn=<DivBackward0>)
# 82 :: tensor(1.3911, grad_fn=<DivBackward0>)
# 83 :: tensor(1.1583, grad_fn=<DivBackward0>)
# 83 :: tensor(1.1486, grad_fn=<DivBackward0>)
# 83 :: tensor(1.2717, grad_fn=<DivBackward0>)
# 83 :: tensor(1.5343, grad_fn=<DivBackward0>)
# 83 :: tensor(1.0816, grad_fn=<DivBackward0>)
# 83 :: tensor(1.1387, grad_fn=<DivBackward0>)
# 83 :: tensor(1.1975, grad_fn=<DivBackward0>)
# 83 :: tensor(1.0935, grad_fn=<DivBackward0>)
# 84 :: tensor(1.2701, grad_fn=<DivBackward0>)
# 84 :: tensor(1.0876, grad_fn=<DivBackward0>)
# 84 :: tensor(1.2181, grad_fn=<DivBackward0>)
# 84 :: tensor(1.2819, grad_fn=<DivBackward0>)
# 84 :: tensor(1.2463, grad_fn=<DivBackward0>)
# 84 :: tensor(1.0391, grad_fn=<DivBackward0>)
# 84 :: tensor(1.1929, grad_fn=<DivBackward0>)
# 84 :: tensor(0.9738, grad_fn=<DivBackward0>)
# 85 :: tensor(1.2085, grad_fn=<DivBackward0>)
# 85 :: tensor(1.1490, grad_fn=<DivBackward0>)
# 85 :: tensor(1.4176, grad_fn=<DivBackward0>)
# 85 :: tensor(1.1917, grad_fn=<DivBackward0>)
# 85 :: tensor(1.0797, grad_fn=<DivBackward0>)
# 85 :: tensor(1.0368, grad_fn=<DivBackward0>)
# 85 :: tensor(1.4081, grad_fn=<DivBackward0>)
# 85 :: tensor(1.1545, grad_fn=<DivBackward0>)
# 86 :: tensor(1.2511, grad_fn=<DivBackward0>)
# 86 :: tensor(1.0395, grad_fn=<DivBackward0>)
# 86 :: tensor(1.2205, grad_fn=<DivBackward0>)
# 86 :: tensor(1.3403, grad_fn=<DivBackward0>)
# 86 :: tensor(1.0316, grad_fn=<DivBackward0>)
# 86 :: tensor(1.1325, grad_fn=<DivBackward0>)
# 86 :: tensor(1.2329, grad_fn=<DivBackward0>)
# 86 :: tensor(0.9137, grad_fn=<DivBackward0>)
# 87 :: tensor(1.3027, grad_fn=<DivBackward0>)
# 87 :: tensor(1.0105, grad_fn=<DivBackward0>)
# 87 :: tensor(1.5747, grad_fn=<DivBackward0>)
# 87 :: tensor(1.3947, grad_fn=<DivBackward0>)
# 87 :: tensor(0.9826, grad_fn=<DivBackward0>)
# 87 :: tensor(1.1864, grad_fn=<DivBackward0>)
# 87 :: tensor(1.2800, grad_fn=<DivBackward0>)
# 87 :: tensor(0.9708, grad_fn=<DivBackward0>)
# 88 :: tensor(1.1821, grad_fn=<DivBackward0>)
# 88 :: tensor(1.1537, grad_fn=<DivBackward0>)
# 88 :: tensor(1.3022, grad_fn=<DivBackward0>)
# 88 :: tensor(1.3119, grad_fn=<DivBackward0>)
# 88 :: tensor(0.9553, grad_fn=<DivBackward0>)
# 88 :: tensor(1.0952, grad_fn=<DivBackward0>)
# 88 :: tensor(1.2191, grad_fn=<DivBackward0>)
# 88 :: tensor(0.9438, grad_fn=<DivBackward0>)
# 89 :: tensor(1.2754, grad_fn=<DivBackward0>)
# 89 :: tensor(1.0454, grad_fn=<DivBackward0>)
# 89 :: tensor(1.4072, grad_fn=<DivBackward0>)
# 89 :: tensor(1.5399, grad_fn=<DivBackward0>)
# 89 :: tensor(1.1519, grad_fn=<DivBackward0>)
# 89 :: tensor(1.1868, grad_fn=<DivBackward0>)
# 89 :: tensor(1.2210, grad_fn=<DivBackward0>)
# 89 :: tensor(1.1740, grad_fn=<DivBackward0>)
# 90 :: tensor(1.2841, grad_fn=<DivBackward0>)
# 90 :: tensor(1.3858, grad_fn=<DivBackward0>)
# 90 :: tensor(1.4189, grad_fn=<DivBackward0>)
# 90 :: tensor(1.3582, grad_fn=<DivBackward0>)
# 90 :: tensor(1.1302, grad_fn=<DivBackward0>)
# 90 :: tensor(1.1391, grad_fn=<DivBackward0>)
# 90 :: tensor(1.5043, grad_fn=<DivBackward0>)
# 90 :: tensor(0.9424, grad_fn=<DivBackward0>)
# 91 :: tensor(1.3003, grad_fn=<DivBackward0>)
# 91 :: tensor(1.1726, grad_fn=<DivBackward0>)
# 91 :: tensor(1.1814, grad_fn=<DivBackward0>)
# 91 :: tensor(1.1270, grad_fn=<DivBackward0>)
# 91 :: tensor(1.0555, grad_fn=<DivBackward0>)
# 91 :: tensor(0.9766, grad_fn=<DivBackward0>)
# 91 :: tensor(1.2439, grad_fn=<DivBackward0>)
# 91 :: tensor(0.9029, grad_fn=<DivBackward0>)
# 92 :: tensor(1.1832, grad_fn=<DivBackward0>)
# 92 :: tensor(1.0482, grad_fn=<DivBackward0>)
# 92 :: tensor(1.2915, grad_fn=<DivBackward0>)
# 92 :: tensor(1.3752, grad_fn=<DivBackward0>)
# 92 :: tensor(0.9366, grad_fn=<DivBackward0>)
# 92 :: tensor(1.0910, grad_fn=<DivBackward0>)
# 92 :: tensor(1.2739, grad_fn=<DivBackward0>)
# 92 :: tensor(0.9454, grad_fn=<DivBackward0>)
# 93 :: tensor(1.1936, grad_fn=<DivBackward0>)
# 93 :: tensor(0.9548, grad_fn=<DivBackward0>)
# 93 :: tensor(1.1197, grad_fn=<DivBackward0>)
# 93 :: tensor(1.1590, grad_fn=<DivBackward0>)
# 93 :: tensor(1.1413, grad_fn=<DivBackward0>)
# 93 :: tensor(1.0561, grad_fn=<DivBackward0>)
# 93 :: tensor(1.3125, grad_fn=<DivBackward0>)
# 93 :: tensor(0.9155, grad_fn=<DivBackward0>)
# 94 :: tensor(1.2453, grad_fn=<DivBackward0>)
# 94 :: tensor(1.0202, grad_fn=<DivBackward0>)
# 94 :: tensor(1.0634, grad_fn=<DivBackward0>)
# 94 :: tensor(1.1165, grad_fn=<DivBackward0>)
# 94 :: tensor(0.9882, grad_fn=<DivBackward0>)
# 94 :: tensor(1.0731, grad_fn=<DivBackward0>)
# 94 :: tensor(1.3964, grad_fn=<DivBackward0>)
# 94 :: tensor(1.0684, grad_fn=<DivBackward0>)
# 95 :: tensor(1.1490, grad_fn=<DivBackward0>)
# 95 :: tensor(1.0285, grad_fn=<DivBackward0>)
# 95 :: tensor(1.1220, grad_fn=<DivBackward0>)
# 95 :: tensor(1.0887, grad_fn=<DivBackward0>)
# 95 :: tensor(1.1418, grad_fn=<DivBackward0>)
# 95 :: tensor(1.1241, grad_fn=<DivBackward0>)
# 95 :: tensor(1.2007, grad_fn=<DivBackward0>)
# 95 :: tensor(0.8650, grad_fn=<DivBackward0>)
# 96 :: tensor(1.2141, grad_fn=<DivBackward0>)
# 96 :: tensor(0.9995, grad_fn=<DivBackward0>)
# 96 :: tensor(1.0930, grad_fn=<DivBackward0>)
# 96 :: tensor(1.0715, grad_fn=<DivBackward0>)
# 96 :: tensor(1.0578, grad_fn=<DivBackward0>)
# 96 :: tensor(1.1554, grad_fn=<DivBackward0>)
# 96 :: tensor(1.3611, grad_fn=<DivBackward0>)
# 96 :: tensor(1.0751, grad_fn=<DivBackward0>)
# 97 :: tensor(1.2552, grad_fn=<DivBackward0>)
# 97 :: tensor(1.1649, grad_fn=<DivBackward0>)
# 97 :: tensor(1.0722, grad_fn=<DivBackward0>)
# 97 :: tensor(1.1398, grad_fn=<DivBackward0>)
# 97 :: tensor(1.0785, grad_fn=<DivBackward0>)
# 97 :: tensor(1.0476, grad_fn=<DivBackward0>)
# 97 :: tensor(1.2858, grad_fn=<DivBackward0>)
# 97 :: tensor(0.9122, grad_fn=<DivBackward0>)
# 98 :: tensor(1.1775, grad_fn=<DivBackward0>)
# 98 :: tensor(1.1644, grad_fn=<DivBackward0>)
# 98 :: tensor(1.2082, grad_fn=<DivBackward0>)
# 98 :: tensor(1.1387, grad_fn=<DivBackward0>)
# 98 :: tensor(0.9777, grad_fn=<DivBackward0>)
# 98 :: tensor(1.0046, grad_fn=<DivBackward0>)
# 98 :: tensor(1.1451, grad_fn=<DivBackward0>)
# 98 :: tensor(0.8500, grad_fn=<DivBackward0>)
# 99 :: tensor(1.0995, grad_fn=<DivBackward0>)
# 99 :: tensor(1.0286, grad_fn=<DivBackward0>)
# 99 :: tensor(1.4331, grad_fn=<DivBackward0>)
# 99 :: tensor(1.1826, grad_fn=<DivBackward0>)
# 99 :: tensor(0.8957, grad_fn=<DivBackward0>)
# 99 :: tensor(1.0267, grad_fn=<DivBackward0>)
# 99 :: tensor(1.1557, grad_fn=<DivBackward0>)
# 99 :: tensor(0.9024, grad_fn=<DivBackward0>)

# %%
#cwrnn = ClockModule(1, STATE, MODULES, 1)
#cwrnn.load_state_dict(torch.load(open('cw_model.mdl', mode='rb')))
#cwrnn.eval()

# %%
plt.plot(losses)#0.243

# %%
torch.set_printoptions(threshold=np.inf)
rnn_c = rnn.cpu()
with torch.no_grad():
    state = torch.zeros(1, 4, STATE)
    factor = 400
    #output = X[p, 0].view(1, 1)
    output = torch.zeros(1, 1)
    outputs = torch.zeros(X.shape[1] * factor, 1)

    for step in range(0, X.shape[1] * factor):
        inpt = muLaw((torch.argmax(output, dim=1).float()/BITR).view(-1, 1))

        pm = torch.tensor([step / (X.shape[1] * factor)]).view(1, 1)
        output, state = rnn_c(inpt, state, pm)

        outputs[step] = (torch.argmax(output, dim=1).float()/BITR).view(-1, 1)

    #plt.plot(X[int(p/2)].cpu())
    plt.plot(outputs)
    plt.show()

# %%
import wave
oput = outputs.detach().numpy()
w = wave.open('output_1_low.wav', 'wb')
w.setparams((1, 2, 16000, oput.shape[0], 'NONE', 'NONE'))
w.writeframes((oput * 30000).astype('int16'))
